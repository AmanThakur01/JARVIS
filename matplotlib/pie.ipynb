# %%
from matplotlib import pyplot as plt
import numpy as np
from matplotlib import style

# %%
class_name=['py','ML','AI','DS']
stds1=[12,10,6,7]
stds2=[17,16,36,27]
explode=[0.1,0,0,0]
colors=['y','g','b','k']
textprops={"fontsize":12}

# %%
plt.pie(stds1,labels=class_name,explode=explode,colors=colors,autopct='%0.2f%%',shadow=True
        ,radius=1,startangle=360,textprops=textprops)
plt.show()
