# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.pie([2,2])
plt.savefig("piech",dpi=1000,quality=99,facecolor='g')
# Out:
# <ipython-input-4-3e7e1c6e1e15>:2: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig("piech",dpi=1000,quality=99,facecolor='g')

# %%
import matplotlib.image as mpimg
img=mpimg.imread("piech.png")
singlChannel=img[:,:,1]

# %%
plt.axis("off")

plt.imshow(singlChannel,cmap='hot')
plt.colorbar()
