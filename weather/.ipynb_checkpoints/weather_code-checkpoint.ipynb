# %%
import json
import requests
import pandas as pd
req = requests.get("https://api.openweathermap.org/data/2.5/forecast?q=bhopal"
                           "&appid=ef831cc525f939c8eb6824aa48c69c82")


text_data= req.text
json_dict= json.loads(text_data)

df = pd.DataFrame.from_dict(json_dict["list"])
df.to_excel("output.xlsx")

# %%
df=df.drop('rain',axis=1).copy()

# %%
df[['temp']] =df.main.str.split("t",expand=True,)[0]
#,'feels_like','temp_min','temp_max','pressure','sea_level','grnd_level','humidity','temp_kf'

# %%
df
# Out:
#             dt                                               main  \
# 0   1621695600  {'temp': 307.28, 'feels_like': 306.44, 'temp_m...
# 1   1621706400  {'temp': 306.42, 'feels_like': 305.2, 'temp_mi...
# 2   1621717200  {'temp': 304.91, 'feels_like': 303.59, 'temp_m...
# 3   1621728000  {'temp': 302.84, 'feels_like': 301.69, 'temp_m...
# 4   1621738800  {'temp': 303.7, 'feels_like': 302.8, 'temp_min...
# 5   1621749600  {'temp': 305.15, 'feels_like': 304.21, 'temp_m...
# 6   1621760400  {'temp': 310.52, 'feels_like': 308.64, 'temp_m...
# 7   1621771200  {'temp': 309.95, 'feels_like': 307.97, 'temp_m...
# 8   1621782000  {'temp': 306.12, 'feels_like': 304.61, 'temp_m...
# 9   1621792800  {'temp': 305.72, 'feels_like': 304.38, 'temp_m...
# 10  1621803600  {'temp': 303.9, 'feels_like': 302.81, 'temp_mi...
# 11  1621814400  {'temp': 302.44, 'feels_like': 301.54, 'temp_m...
# 12  1621825200  {'temp': 306.08, 'feels_like': 304.68, 'temp_m...
# 13  1621836000  {'temp': 310.4, 'feels_like': 308.86, 'temp_mi...
# 14  1621846800  {'temp': 312.34, 'feels_like': 310.21, 'temp_m...
# 15  1621857600  {'temp': 311, 'feels_like': 308.86, 'temp_min'...
# 16  1621868400  {'temp': 307.82, 'feels_like': 305.63, 'temp_m...
# 17  1621879200  {'temp': 305.99, 'feels_like': 303.87, 'temp_m...
# 18  1621890000  {'temp': 303.81, 'feels_like': 302.18, 'temp_m...
# 19  1621900800  {'temp': 303.54, 'feels_like': 302.44, 'temp_m...
# 20  1621911600  {'temp': 307.63, 'feels_like': 305.97, 'temp_m...
# 21  1621922400  {'temp': 311.74, 'feels_like': 309.71, 'temp_m...
# 22  1621933200  {'temp': 313.39, 'feels_like': 310.98, 'temp_m...
# 23  1621944000  {'temp': 312.53, 'feels_like': 309.86, 'temp_m...
# 24  1621954800  {'temp': 309.23, 'feels_like': 306.81, 'temp_m...
# 25  1621965600  {'temp': 307.15, 'feels_like': 304.95, 'temp_m...
# 26  1621976400  {'temp': 305.33, 'feels_like': 303.74, 'temp_m...
# 27  1621987200  {'temp': 303.63, 'feels_like': 302.28, 'temp_m...
# 28  1621998000  {'temp': 305.68, 'feels_like': 305.31, 'temp_m...
# 29  1622008800  {'temp': 311.73, 'feels_like': 310.34, 'temp_m...
# 30  1622019600  {'temp': 313.97, 'feels_like': 311.88, 'temp_m...
# 31  1622030400  {'temp': 312.76, 'feels_like': 310.7, 'temp_mi...
# 32  1622041200  {'temp': 309.92, 'feels_like': 307.94, 'temp_m...
# 33  1622052000  {'temp': 307.8, 'feels_like': 306.31, 'temp_mi...
# 34  1622062800  {'temp': 305.37, 'feels_like': 304.22, 'temp_m...
# 35  1622073600  {'temp': 302.35, 'feels_like': 303.07, 'temp_m...
# 36  1622084400  {'temp': 302.61, 'feels_like': 304.32, 'temp_m...
# 37  1622095200  {'temp': 308.77, 'feels_like': 310.3, 'temp_mi...
# 38  1622106000  {'temp': 311.63, 'feels_like': 312.09, 'temp_m...
# 39  1622116800  {'temp': 304.85, 'feels_like': 304.68, 'temp_m...
#
#                                               weather        clouds  \
# 0   [{'id': 801, 'main': 'Clouds', 'description': ...   {'all': 20}
# 1   [{'id': 802, 'main': 'Clouds', 'description': ...   {'all': 46}
# 2   [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 55}
# 3   [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 71}
# 4   [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 95}
# 5   [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 96}
# 6   [{'id': 802, 'main': 'Clouds', 'description': ...   {'all': 50}
# 7   [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 51}
# 8   [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 55}
# 9   [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 77}
# 10  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 89}
# 11  [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 78}
# 12  [{'id': 802, 'main': 'Clouds', 'description': ...   {'all': 33}
# 13  [{'id': 801, 'main': 'Clouds', 'description': ...   {'all': 20}
# 14  [{'id': 800, 'main': 'Clear', 'description': '...    {'all': 6}
# 15  [{'id': 802, 'main': 'Clouds', 'description': ...   {'all': 30}
# 16  [{'id': 800, 'main': 'Clear', 'description': '...    {'all': 7}
# 17  [{'id': 801, 'main': 'Clouds', 'description': ...   {'all': 24}
# 18  [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 81}
# 19  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 90}
# 20  [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 78}
# 21  [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 72}
# 22  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 89}
# 23  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 94}
# 24  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 25  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 26  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 27  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 28  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 29  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 85}
# 30  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 95}
# 31  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 97}
# 32  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 33  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 34  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 35  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 36  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 37  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 99}
# 38  [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 77}
# 39  [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 67}
#
#                                           wind  visibility   pop  \
# 0    {'speed': 2.06, 'deg': 262, 'gust': 3.03}       10000  0.00
# 1    {'speed': 3.43, 'deg': 289, 'gust': 6.66}       10000  0.00
# 2     {'speed': 2.03, 'deg': 311, 'gust': 3.1}       10000  0.04
# 3    {'speed': 2.96, 'deg': 326, 'gust': 5.73}       10000  0.00
# 4   {'speed': 6.86, 'deg': 292, 'gust': 10.04}       10000  0.00
# 5    {'speed': 4.59, 'deg': 333, 'gust': 5.53}       10000  0.00
# 6     {'speed': 2.7, 'deg': 307, 'gust': 5.09}       10000  0.00
# 7     {'speed': 3.79, 'deg': 308, 'gust': 4.5}       10000  0.00
# 8    {'speed': 3.13, 'deg': 242, 'gust': 5.05}       10000  0.00
# 9    {'speed': 4.06, 'deg': 268, 'gust': 7.38}       10000  0.00
# 10   {'speed': 4.39, 'deg': 318, 'gust': 7.87}       10000  0.00
# 11  {'speed': 5.03, 'deg': 316, 'gust': 10.56}       10000  0.00
# 12   {'speed': 6.86, 'deg': 336, 'gust': 9.18}       10000  0.00
# 13   {'speed': 6.26, 'deg': 339, 'gust': 5.97}       10000  0.00
# 14   {'speed': 5.91, 'deg': 329, 'gust': 6.75}       10000  0.00
# 15   {'speed': 6.84, 'deg': 345, 'gust': 7.37}       10000  0.00
# 16   {'speed': 3.67, 'deg': 342, 'gust': 7.87}       10000  0.00
# 17   {'speed': 3.14, 'deg': 351, 'gust': 5.94}       10000  0.00
# 18   {'speed': 3.56, 'deg': 299, 'gust': 7.19}       10000  0.00
# 19  {'speed': 4.83, 'deg': 300, 'gust': 10.63}       10000  0.00
# 20   {'speed': 5.94, 'deg': 330, 'gust': 7.46}       10000  0.00
# 21    {'speed': 6.4, 'deg': 336, 'gust': 7.54}       10000  0.00
# 22   {'speed': 7.42, 'deg': 336, 'gust': 7.87}       10000  0.00
# 23   {'speed': 7.42, 'deg': 339, 'gust': 8.87}       10000  0.00
# 24   {'speed': 4.25, 'deg': 338, 'gust': 9.64}       10000  0.00
# 25  {'speed': 4.18, 'deg': 318, 'gust': 10.53}       10000  0.00
# 26  {'speed': 8.26, 'deg': 294, 'gust': 15.38}       10000  0.00
# 27  {'speed': 7.95, 'deg': 293, 'gust': 15.39}       10000  0.00
# 28  {'speed': 8.56, 'deg': 292, 'gust': 11.42}       10000  0.00
# 29   {'speed': 7.43, 'deg': 306, 'gust': 6.99}       10000  0.00
# 30   {'speed': 6.33, 'deg': 310, 'gust': 6.84}       10000  0.00
# 31   {'speed': 6.53, 'deg': 295, 'gust': 7.02}       10000  0.00
# 32   {'speed': 5.59, 'deg': 294, 'gust': 9.81}       10000  0.00
# 33   {'speed': 8.13, 'deg': 286, 'gust': 13.3}       10000  0.00
# 34  {'speed': 8.29, 'deg': 294, 'gust': 14.49}       10000  0.00
# 35  {'speed': 6.64, 'deg': 287, 'gust': 12.33}       10000  0.00
# 36   {'speed': 6.78, 'deg': 286, 'gust': 8.64}       10000  0.00
# 37       {'speed': 6.7, 'deg': 287, 'gust': 7}       10000  0.00
# 38   {'speed': 5.83, 'deg': 298, 'gust': 5.36}       10000  0.00
# 39   {'speed': 8.87, 'deg': 15, 'gust': 11.52}       10000  0.32
#
#              sys               dt_txt  temp
# 0   {'pod': 'n'}  2021-05-22 15:00:00   NaN
# 1   {'pod': 'n'}  2021-05-22 18:00:00   NaN
# 2   {'pod': 'n'}  2021-05-22 21:00:00   NaN
# 3   {'pod': 'n'}  2021-05-23 00:00:00   NaN
# 4   {'pod': 'd'}  2021-05-23 03:00:00   NaN
# 5   {'pod': 'd'}  2021-05-23 06:00:00   NaN
# 6   {'pod': 'd'}  2021-05-23 09:00:00   NaN
# 7   {'pod': 'd'}  2021-05-23 12:00:00   NaN
# 8   {'pod': 'n'}  2021-05-23 15:00:00   NaN
# 9   {'pod': 'n'}  2021-05-23 18:00:00   NaN
# 10  {'pod': 'n'}  2021-05-23 21:00:00   NaN
# 11  {'pod': 'n'}  2021-05-24 00:00:00   NaN
# 12  {'pod': 'd'}  2021-05-24 03:00:00   NaN
# 13  {'pod': 'd'}  2021-05-24 06:00:00   NaN
# 14  {'pod': 'd'}  2021-05-24 09:00:00   NaN
# 15  {'pod': 'd'}  2021-05-24 12:00:00   NaN
# 16  {'pod': 'n'}  2021-05-24 15:00:00   NaN
# 17  {'pod': 'n'}  2021-05-24 18:00:00   NaN
# 18  {'pod': 'n'}  2021-05-24 21:00:00   NaN
# 19  {'pod': 'n'}  2021-05-25 00:00:00   NaN
# 20  {'pod': 'd'}  2021-05-25 03:00:00   NaN
# 21  {'pod': 'd'}  2021-05-25 06:00:00   NaN
# 22  {'pod': 'd'}  2021-05-25 09:00:00   NaN
# 23  {'pod': 'd'}  2021-05-25 12:00:00   NaN
# 24  {'pod': 'n'}  2021-05-25 15:00:00   NaN
# 25  {'pod': 'n'}  2021-05-25 18:00:00   NaN
# 26  {'pod': 'n'}  2021-05-25 21:00:00   NaN
# 27  {'pod': 'n'}  2021-05-26 00:00:00   NaN
# 28  {'pod': 'd'}  2021-05-26 03:00:00   NaN
# 29  {'pod': 'd'}  2021-05-26 06:00:00   NaN
# 30  {'pod': 'd'}  2021-05-26 09:00:00   NaN
# 31  {'pod': 'd'}  2021-05-26 12:00:00   NaN
# 32  {'pod': 'n'}  2021-05-26 15:00:00   NaN
# 33  {'pod': 'n'}  2021-05-26 18:00:00   NaN
# 34  {'pod': 'd'}  2021-05-26 21:00:00   NaN
# 35  {'pod': 'd'}  2021-05-27 00:00:00   NaN
# 36  {'pod': 'd'}  2021-05-27 03:00:00   NaN
# 37  {'pod': 'd'}  2021-05-27 06:00:00   NaN
# 38  {'pod': 'd'}  2021-05-27 09:00:00   NaN
# 39  {'pod': 'd'}  2021-05-27 12:00:00   NaN

# %%
speed=df.wind
wind_speed=[]
for i in speed:
    wind_speed.append(i['speed'])

# %%
# for ind,i in enumerate(text):
#     j=i['temp']
#     print(j)
#     print(ind)

# %%
import seaborn as sns

sns.set_theme(style="darkgrid")

# %%
sns.displot(
    df, x="flipper_length_mm", col="species", row="sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e7c48f9eb274> in <module>
# ----> 1 sns.displot(
#       2     df, x="flipper_length_mm", col="species", row="sex",
#       3     binwidth=3, height=3, facet_kws=dict(margin_titles=True),
#       4 )
#
# ~/.local/lib/python3.8/site-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2145 ):
#    2146
# -> 2147     p = _DistributionFacetPlotter(
#    2148         data=data,
#    2149         variables=_DistributionFacetPlotter.get_semantics(locals())
#
# ~/.local/lib/python3.8/site-packages/seaborn/distributions.py in __init__(self, data, variables)
#     107     ):
#     108
# --> 109         super().__init__(data=data, variables=variables)
#     110
#     111     @property
#
# ~/.local/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~/.local/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~/.local/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `flipper_length_mm` for parameter `x`

# %% [markdown]
# # speed=m/s,temp=kelvin
